# %% [markdown]
# # Week 5 Peer Graded Assignment: GANs

# %% [markdown]
# ## Project Introduction - Description of the Problem

# %% [markdown]
# In this project, I'm working with generative adversarial networks (GANs). The challenge is to produce images that are convincingly real, as judged by pre-trained neural networks. Dogs are the best and in case, we're using them in this project because of their diverse range in breeds, colors, and sizes. All of these elements make them pretty good subjects for image generation.
#
# GANS have so many different applications and can be used in all kinds of industries where we want to replicate data. For this project, I'm going to be playing around to make realistic dog images. This is an example of deep learning that I would like to gain more knowledge about.

# %% [markdown]
# ## Data

# %% [markdown]
# This dataset originates from a Kaggle competition focused on generative dog images. The dataset has no redundant data. There's over 20,000 training images. The dataset has 120 different dog breeds from all parts of the world.
#
# Here's the link to the dataset: https://www.kaggle.com/competitions/generative-dog-images/data

# %% [markdown]
# ## Exploratory Data Analysis (EDA) — Inspect, Visualize and Clean the Data

# %% [markdown]
# I got stuck on working with the zipped dataset. If I had gone through further on this assignment. I would be looking at some images to get an idea of how they look and get a feel for it. After that, I would preprocess the images by narmalizing them and get them ready for building models.

# %%
# !unzip /kaggle/input/generative-dog-images/Annotation.zip -d /kaggle/working/Annotation/
# !unzip /kaggle/input/generative-dog-images/all-dogs.zip -d /kaggle/working/all-dogs/
# Out:
# Archive:  /kaggle/input/generative-dog-images/Annotation.zip
# replace /kaggle/working/Annotation/Annotation/n02097658-silky_terrier/n02097658_98? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C
# Archive:  /kaggle/input/generative-dog-images/all-dogs.zip
# replace /kaggle/working/all-dogs/all-dogs/n02109961_16718.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %% [markdown]
# ## My Plan of Analysis and Model Architecture

# %% [markdown]
# My plan of analysis for my GAN involves building the core first, which would be the generator and discriminator. I would first generate images and then use the discriminator to figure out how real an image is.
